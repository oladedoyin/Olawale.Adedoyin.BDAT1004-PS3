# %% [markdown]
# Question 1
#
# Introduction: Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users
# Step 4. Discover what is the mean age per occupation
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least
# Step 6. For each occupation, calculate the minimum and maximum ages
# Step 7. For each combination of occupation and sex, calculate the mean age
# Step 8. For each occupation present the percentage of women and men

# %%
#step1 - import library
import pandas as pd

# %%
#step2 - import the dataset from url
#step3 - assign it to a variable called users
url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user"
users = pd.read_csv(url, sep='|')

# %%
print(users)
# Out:
#      user_id  age gender     occupation zip_code
# 0          1   24      M     technician    85711
# 1          2   53      F          other    94043
# 2          3   23      M         writer    32067
# 3          4   24      M     technician    43537
# 4          5   33      F          other    15213
# ..       ...  ...    ...            ...      ...
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841
#
# [943 rows x 5 columns]

# %%
users.head()
users.tail()
# Out:
#      user_id  age gender     occupation zip_code
# 938      939   26      F        student    33319
# 939      940   32      M  administrator    02215
# 940      941   20      M        student    97229
# 941      942   48      F      librarian    78209
# 942      943   22      M        student    77841

# %%
#step4 - mean age per occupation
mean_age_per_occupation = users.groupby('occupation')['age'].mean()
print("Mean age per occupation:")
print(mean_age_per_occupation)
# Out:
# Mean age per occupation:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %%
#step5 -  Male ratio per occupation and sort it from the most to the least
def male_ratio(group):
    male_count = (group['gender'] == 'M').sum()
    total_count = group['gender'].count()
    return male_count / total_count

male_ratio_per_occupation = users.groupby('occupation').apply(male_ratio).sort_values(ascending=False)
print(male_ratio_per_occupation)
# Out:
# occupation
# doctor           1.000000
# engineer         0.970149
# technician       0.962963
# retired          0.928571
# programmer       0.909091
# executive        0.906250
# scientist        0.903226
# entertainment    0.888889
# lawyer           0.833333
# salesman         0.750000
# educator         0.726316
# student          0.693878
# other            0.657143
# marketing        0.615385
# writer           0.577778
# none             0.555556
# administrator    0.544304
# artist           0.535714
# librarian        0.431373
# healthcare       0.312500
# homemaker        0.142857
# dtype: float64

# %%
#step6 - for each occupation, calculate the minimum and maximum ages
min_max_ages_per_occupation = users.groupby('occupation').age.agg(['min', 'max'])
print("\nMinimum and maximum ages per occupation:")
print(min_max_ages_per_occupation)
# Out:
# Minimum and maximum ages per occupation:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
#step7 - for each combination of occupation and sex, calculate the mean age
mean_age_per_occupation_sex = users.groupby(['occupation', 'gender']).age.mean()
print("\nMean age per occupation and sex:")
print( )
print(mean_age_per_occupation_sex)
# Out:
# Mean age per occupation and sex:
#
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# ...

# %%
#step8 - for each occupation present the percentage of women and men

#create a DataFrame, then apply count to gender
gender_occupation = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})

#create a DataFrame, then apply count for each occupation
total_count_occupation = users.groupby(['occupation']).count()

#divide the gender_occupation by the occupation_count and multiply by 100
gender_occupation = round((gender_occupation.div(total_count_occupation, level = "occupation")*100),1)
gender_occupation.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F          45.6
#                M          54.4
# artist         F          46.4
#                M          53.6
# doctor         M         100.0
# educator       F          27.4
#                M          72.6
# engineer       F           3.0
#                M          97.0
# entertainment  F          11.1
#                M          88.9
# executive      F           9.4
#                M          90.6
# healthcare     F          68.8
#                M          31.2
# homemaker      F          85.7
#                M          14.3
# lawyer         F          16.7
#                M          83.3
# librarian      F          56.9
#                M          43.1
# marketing      F          38.5
#                M          61.5
# none           F          44.4
#                M          55.6
# other          F          34.3
#                M          65.7
# programmer     F           9.1
#                M          90.9
# ...

# %% [markdown]
# Question 2
#
# Euro Teams
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address
# Step 3. Assign it to a variable called euro12
# Step 4. Select only the Goal column
# Step 5. How many team participated in the Euro2012?
# Step 6. What is the number of columns in the dataset?
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
# Step 8. Sort the teams by Red Cards, then to Yellow Cards
# Step 9. Calculate the mean Yellow Cards given per Team
# Step 10. Filter teams that scored more than 6 goals
# Step 11. Select the teams that start with G
# Step 12. Select the first 7 columns
# Step 13. Select all columns except the last 3
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
#step 1 - import the necessary libraries
import pandas as pd

# %%
#step 2 - import dataset from url
#step 3 - assign it to a variable called euro12
dataset_url = "https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv"
euro12 = pd.read_csv(dataset_url)
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
#step 4 - select only the goal column
goal_column = euro12['Goals']
print("Goal column:")
print(goal_column)
# Out:
# Goal column:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
#step5 - count of teams particpated in Euro2012
euro12['Team'].count()
# Out:
# 16

# %%
#step6 - number of columns in the dataset
num_columns = len(euro12.columns)
print("\nNumber of columns in the dataset:", num_columns)
# Out:
# Number of columns in the dataset: 35

# %%
#step7 - view only columns Team, Yellow Cards and Red Cards and assign them to a dataframe called discipline
discipline = euro12[['Team', 'Yellow Cards', 'Red Cards']]
print("\nDataFrame 'displine':")
print(discipline)
# Out:
# DataFrame 'displine':
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %%
#step8 - sort the teams by Red cards, then to yellow cards
discipline_sorted = discipline.sort_values(by=['Red Cards', 'Yellow Cards'], ascending=[False, False])
print(discipline_sorted)
# Out:
#                    Team  Yellow Cards  Red Cards
# 6                Greece             9          1
# 9                Poland             7          1
# 11  Republic of Ireland             6          1
# 7                 Italy            16          0
# 10             Portugal            12          0
# 13                Spain            11          0
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 4                France             6          0
# 12               Russia             6          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 2               Denmark             4          0
# 5               Germany             4          0

# %%
#step9 - calculate the mean Yellow Cards given per Team
mean_yellow_cards_per_team = euro12.groupby('Team')['Yellow Cards'].mean()
print("\nMean Yellow Cards given per Team:")
print(mean_yellow_cards_per_team)
# Out:
# Mean Yellow Cards given per Team:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %%
#step10 - filter teams that scored more than 6 goals
euro12[euro12['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
#step11 - select the teams that start with G
euro12[euro12['Team'].str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
#step 12 - select first 7 columns
euro12.iloc[ : , : 7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step13 - select all the cols except the last 3
euro12.iloc[:, :-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
#step14 - present only the shooting accuracy from England, Italy and Russia
choosen_teams = ['England', 'Italy', 'Russia']
shooting_accuracy_choosen_teams = euro12[euro12['Team'].isin(choosen_teams)][['Team', 'Shooting Accuracy']]
print(shooting_accuracy_choosen_teams)
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# Question 3
#
# Housing
# Step 1. Import the necessary libraries
# Step 2. Create 3 differents Series, each of length 100, as follows: • The first a random number from 1 to 4 • The second a random number from 1 to 3 • The third a random number from 10,000 to 30,000
# Step 3. Create a DataFrame by joinning the Series by column
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it to 'bigcolumn'
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
#Step1 - import libraries
import pandas as pd
import random

# %%
#step2 - create 3 different series, each of length 100
#create dataframes as stated
first = [[random.randint(1, 4)] for i in range(100)]
df_1 = pd.DataFrame(first)

second = [[random.randint(1, 3)] for i in range(100)]
df_2 = pd.DataFrame(second)

third = [[random.randint(10000, 30000)] for i in range(100)]
df_3 = pd.DataFrame(third)

# %%
#step3 - create DataFrame by joining the series by column
df = pd.concat([df_1, df_2, df_3], axis=1)
df
# Out:
#     0  0      0
# 0   1  1  26348
# 1   2  3  10194
# 2   4  2  27534
# 3   1  1  16806
# 4   3  2  13558
# .. .. ..    ...
# 95  1  1  21184
# 96  2  1  13468
# 97  4  2  24195
# 98  3  3  22308
# 99  1  1  11704
#
# [100 rows x 3 columns]

# %%
#step4 - change the name of columns
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       1       1            26348
# 1       2       3            10194
# 2       4       2            27534
# 3       1       1            16806
# 4       3       2            13558
# ..    ...     ...              ...
# 95      1       1            21184
# 96      2       1            13468
# 97      4       2            24195
# 98      3       3            22308
# 99      1       1            11704
#
# [100 rows x 3 columns]

# %%
#step5 - create a one colum DataFrame with the values of the 3series and asign it to 'bigcolumn'
dataFrame_new = df.bedrs.astype(str).str.cat(df.bathrs.astype(str)).str.cat(df.price_sqr_meter.astype(str))
dataFrame_new.columns = ['bigcolumn']
dataFrame_new
# Out:
# 0     1126348
# 1     2310194
# 2     4227534
# 3     1116806
# 4     3213558
#        ...
# 95    1121184
# 96    2113468
# 97    4224195
# 98    3322308
# 99    1111704
# Name: bedrs, Length: 100, dtype: object

# %%
#step6 - checking if it goes only until index 99
print("Is it true that bigcolumn goes only until index 99 :", dataFrame_new.index.max() == 99)
# Out:
# Is it true that bigcolumn goes only until index 99 : True

# %%
#step7 - reindex the DataFrame so it goes from 0 to 299
dataFrame_new = dataFrame_new.reset_index(drop=True)
dataFrame_new.reset_index()
dataFrame_new.reindex(index=range(0,300))
# Out:
# 0      1126348
# 1      2310194
# 2      4227534
# 3      1116806
# 4      3213558
#         ...
# 295        NaN
# 296        NaN
# 297        NaN
# 298        NaN
# 299        NaN
# Name: bedrs, Length: 300, dtype: object

# %% [markdown]
# Question 4
#
# Wind Statistics
# The data have been modified to contain some missing values, identified by NaN. Using pandas should make this exercise easier, in particular for the bonus question.  You should be able to perform all of these operations without using a for loop or other looping construct.  The data in 'wind.data' has the following format:  Yr Mo Dy   RPT   VAL   ROS   KIL   SHA   BIR   DUB   CLA   MUL   CLO   BEL   MAL 61  1  1 15.04 14.96 13.17  9.29   NaN  9.87 13.67 10.25 10.83 12.58 18.50 15.04 61  1  2 14.71   NaN 10.83  6.50 12.62  7.67 11.50 10.04  9.79  9.67 17.54 13.83 61  1  3 18.50 16.88 12.33 10.13 11.17  6.17 11.25   NaN  8.50  7.67 12.75 12.71
#
# The first three columns are year, month, and day. The remaining 12 columns are average windspeeds in knots at 12 locations in Ireland on that day.
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from the attached file wind.txt
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper datetime index.
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it and apply it.
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
# Step 6. Compute how many values are missing for each location over the entire record.They should be ignored in all calculations below.
# Step 7. Compute how many non-missing values there are in total.
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and all the times. A single number for the entire dataset.
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days A different set of numbers for each location.
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.
# Step 11. Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.
# Step 12. Downsample the record to a yearly frequency for each location.
# Step 13. Downsample the record to a monthly frequency for each location.
# Step 14. Downsample the record to a weekly frequency for each location.
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.

# %%
#step 1 - importing the necessary libraries
import pandas as pd
import numpy as np

# %%
#step 2 - import the dataset
data = pd.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data', sep = '\s+')
data.tail()
# Out:
#       Yr  Mo  Dy    RPT    VAL    ROS   KIL    SHA    BIR    DUB    CLA  \
# 6569  78  12  27  17.58  16.96  17.62  8.08  13.21  11.67  14.46  15.59
# 6570  78  12  28  13.21   5.46  13.46  5.00   8.12   9.42  14.33  16.25
# 6571  78  12  29  14.00  10.29  14.42  8.71   9.71  10.54  19.17  12.46
# 6572  78  12  30  18.50  14.04  21.29  9.13  12.75   9.71  18.08  12.87
# 6573  78  12  31  20.33  17.41  27.29  9.59  12.08  10.13  19.25  11.63
#
#         MUL    CLO    BEL    MAL
# 6569  14.04  14.00  17.21  40.08
# 6570  15.25  18.05  21.79  41.46
# 6571  14.50  16.42  18.88  29.58
# 6572  12.46  12.12  14.67  28.79
# 6573  11.58  11.38  12.08  22.08

# %%
#step 3 - assign it to a variable called data and replace the first 3 columns by a proper datetime index
data["Date"] = pd.to_datetime(data[['Yr', 'Mo', 'Dy']].astype(str).agg('-'.join, axis=1))
data = data.drop(columns=['Yr', 'Mo', 'Dy'])
data = data[['Date', 'RPT', 'VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
#step 4 - Year 2061? Do we really have data from this year? Create a function to fix it and apply it
data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000,
                        data.Date,data.Date - pd.offsets.DateOffset(years=100))
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 1961-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 1961-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 1961-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 1961-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 1961-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %%
#step 5 - Set the right dates as the index. Pay attention at the data type, it should be datetime64[ns].
NData = data.set_index("Date")
NData.index.astype("datetime64[ns]")
# Out:
# DatetimeIndex(['1961-01-01', '1961-01-02', '1961-01-03', '1961-01-04',
#                '1961-01-05', '1961-01-06', '1961-01-07', '1961-01-08',
#                '1961-01-09', '1961-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %%
#step 6 - compute how many values are missing for each location over the entire record. They should be ignored in all calculations below
NData.isnull().values.ravel().sum()
# Out:
# 31

# %%
#step 7 - compute how many non-missing values there are in total
nData = NData.count()
print("Total Non-missing values is :", nData.sum())
# Out:
# Total Non-missing values is : 78857

# %%
#step 8 - Calculate the mean windspeeds of the windspeeds over all the locations and all the times.
a = round(NData.mean(),2)
a
# Out:
# RPT    12.36
# VAL    10.64
# ROS    11.66
# KIL     6.31
# SHA    10.46
# BIR     7.09
# DUB     9.80
# CLA     8.50
# MUL     8.49
# CLO     8.71
# BEL    13.12
# MAL    15.60
# dtype: float64

# %%
#A single number for the entire data set
round(a.mean(),2)
# Out:
# 10.23

# %%
#step 9 - Create a DataFrame called loc_stats and calculate the min, max and mean windspeeds and standard deviations of the windspeeds at each location over all the days A different set of numbers for each location. 
def statsKPI(a):
    a = pd.Series(a)
    Mean = a.mean()
    Std = a.std()
    Min = a.min()
    Max = a.max()
    res = [Min,Max,Mean,Std]
    indx = ["MEAN","Std","Min","Max"]
    result = pd.Series(res,index=indx)
    return result

# %%
#different set of numbers for each location.
loc_stats = NData.apply(statsKPI)
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# MEAN   0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# Std   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# Min   12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# Max    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# MEAN   0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# Std   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# Min    9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# Max    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %%
#Step 10 - Create a DataFrame called day_stats and calculate the min, max and mean windspeed and standard deviations of the windspeeds across all the locations at each day. A different set of numbers for each day.
day_stats = NData.apply(statsKPI,axis=1)
day_stats.tail()
# Out:
#             MEAN    Std        Min       Max
# Date
# 1978-12-27  8.08  40.08  16.708333  7.868076
# 1978-12-28  5.00  41.46  15.150000  9.687857
# 1978-12-29  8.71  29.58  14.890000  5.756836
# 1978-12-30  9.13  28.79  15.367500  5.540437
# 1978-12-31  9.59  27.29  15.402500  5.702483

# %%
#step 11 - Find the average windspeed in January for each location. Treat January 1961 and January 1962 both as January.
january_AVG_windspeed = NData[NData.index.month == 1]
round(january_AVG_windspeed.mean(),2)
# Out:
# RPT    14.85
# VAL    12.91
# ROS    13.30
# KIL     7.20
# SHA    11.67
# BIR     8.05
# DUB    11.82
# CLA     9.51
# MUL     9.54
# CLO    10.05
# BEL    14.55
# MAL    18.03
# dtype: float64

# %%
#step 12 - Downsample the record to a yearly frequency for each location
print( "Yearly Frequency:\n", NData.resample('A').mean())
# Out:
# Yearly Frequency:
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1961-12-31  12.299583  10.351796  11.362369  6.958227  10.881763  7.729726
# 1962-12-31  12.246923  10.110438  11.732712  6.960440  10.657918  7.393068
# 1963-12-31  12.813452  10.836986  12.541151  7.330055  11.724110  8.434712
# 1964-12-31  12.363661  10.920164  12.104372  6.787787  11.454481  7.570874
# 1965-12-31  12.451370  11.075534  11.848767  6.858466  11.024795  7.478110
# 1966-12-31  13.461973  11.557205  12.020630  7.345726  11.805041  7.793671
# 1967-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 1968-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 1969-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 1970-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 1971-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
# ...

# %%
#step 13 - Downsample the record to a monthly frequency for each location
print("Monthly Frequency:\n", NData.resample('M').mean())
# Out:
# Monthly Frequency:
#                    RPT        VAL        ROS       KIL        SHA        BIR  \
# Date
# 1961-01-31  14.841333  11.988333  13.431613  7.736774  11.072759   8.588065
# 1961-02-28  16.269286  14.975357  14.441481  9.230741  13.852143  10.937500
# 1961-03-31  10.890000  11.296452  10.752903  7.284000  10.509355   8.866774
# 1961-04-30  10.722667   9.427667   9.998000  5.830667   8.435000   6.495000
# 1961-05-31   9.860968   8.850000  10.818065  5.905333   9.490323   6.574839
# ...               ...        ...        ...       ...        ...        ...
# 1978-08-31   9.645161   8.259355   9.032258  4.502903   7.368065   5.935161
# 1978-09-30  10.913667  10.895000  10.635000  5.725000  10.372000   9.278333
# 1978-10-31   9.897742   8.670968   9.295806  4.721290   8.525161   6.774194
# 1978-11-30  16.151667  14.802667  13.508000  7.317333  11.475000   8.743000
# 1978-12-31  16.175484  13.748065  15.635161  7.094839  11.398710   9.241613
#
# ...

# %%
#step 14 - Downsample the record to a weekly frequency for each location
print("Weekly Frequency:\n", NData.resample('W').mean())
# Out:
# Weekly Frequency:
#                    RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1961-01-01  15.040000  14.960000  13.170000   9.290000        NaN   9.870000
# 1961-01-08  13.541429  11.486667  10.487143   6.417143   9.474286   6.435714
# 1961-01-15  12.468571   8.967143  11.958571   4.630000   7.351429   5.072857
# 1961-01-22  13.204286   9.862857  12.982857   6.328571   8.966667   7.417143
# 1961-01-29  19.880000  16.141429  18.225714  12.720000  17.432857  14.828571
# ...               ...        ...        ...        ...        ...        ...
# 1978-12-03  14.934286  11.232857  13.941429   5.565714  10.215714   8.618571
# 1978-12-10  20.740000  19.190000  17.034286   9.777143  15.287143  12.774286
# 1978-12-17  16.758571  14.692857  14.987143   6.917143  11.397143   7.272857
# 1978-12-24  11.155714   8.008571  13.172857   4.004286   7.825714   6.290000
# 1978-12-31  14.951429  11.801429  16.035714   6.507143   9.660000   8.620000
#
# ...

# %%
#step 15 - Calculate the min, max and mean windspeeds and standard deviations of the windspeeds across all locations for each week (assume that the first week starts on January 2 1961) for the first 52 weeks.
statistic1 = NData.resample('W').mean().apply(lambda x: [x.count(),x.min(),x.max(),x.mean(),x.std()])
print(statistic1)
# Out:
#           RPT         VAL         ROS         KIL         SHA         BIR  \
# 0  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# 1    3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 2   24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
# 3   12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# 4    3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
#
#           DUB         CLA         MUL         CLO         BEL         MAL
# 0  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# 1    2.471429    2.284286    2.262857    1.571429    3.661429    5.124286
# 2   20.474286   17.861429   17.460000   17.932857   26.617143   30.374286
# 3    9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# 4    3.308180    2.853029    2.638349    2.924546    3.757189    4.468526

# %%
first_yr = NData[NData.index.year == 1961]
statistic1 = NData.resample('W').mean().apply(lambda x: x.describe())
print(statistic1)
# Out:
#               RPT         VAL         ROS         KIL         SHA         BIR  \
# count  940.000000  940.000000  940.000000  940.000000  939.000000  940.000000
# mean    12.365304   10.647725   11.661255    6.309334   10.455607    7.094787
# std      3.466600    3.372501    2.840361    2.186432    3.146715    2.556633
# min      3.874286    2.452857    4.901429    1.447143    2.775714    1.382857
# 25%      9.884286    8.277857    9.613929    4.742857    8.248571    5.211071
# 50%     12.291429   10.486429   11.490000    6.165714   10.254286    6.933571
# 75%     14.547143   12.757857   13.457143    7.584286   12.627143    8.842500
# max     24.010000   23.715714   21.384286   14.517143   22.897143   16.010000
#
#               DUB         CLA         MUL         CLO         BEL         MAL
# count  940.000000  940.000000  940.000000  940.000000  940.000000  940.000000
# mean     9.801271    8.496123    8.496452    8.710639   13.125912   15.597171
# ...

# %% [markdown]
# Question 5
#
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called chipo.
# Step 4. See the first 10 entries
# Step 5. What is the number of observations in the dataset?
# Step 6. What is the number of columns in the dataset?
# Step 7. Print the name of all the columns.
# Step 8. How is the dataset indexed?
# Step 9. Which was the most-ordered item?
# Step 10. For the most-ordered item, how many items were ordered?
# Step 11. What was the most ordered item in the choice_description column? Step 12. How many items were orderd in total?
# Step 13. • Turn the item price into a float • Check the item price type • Create a lambda function and change the type of item price • Check the item price type
# Step 14. How much was the revenue for the period in the dataset?
# Step 15. How many orders were made in the period?
# Step 16. What is the average revenue amount per order?
# Step 17. How many different items are sold?

# %%
#step 1 - import the necessary library
import pandas as pd

# %%
#step 2 - import the dataset
#step 3 - assign it to a variable called chipo
data_url = "https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv"
chipo = pd.read_csv(data_url, sep='\t')

# %%
#step 4 - first 10 entries
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
#step 5 - What is the number of observation in the dataset?
print ("\nNumber of observation in the dataset is", chipo.shape[0])
# Out:
# Number of observation in the dataset is 4622

# %%
#step 6 - number of columns in the dataset
print("\nNumber of columns in the dataset is", chipo.shape[1])
# Out:
# Number of columns in the dataset is 5

# %%
#step 7 - print the name of all the columns
chipo.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#step 8 - how is the dataset indexed?
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#step 9 - which was the most ordered item?
item = chipo['item_name'].mode().iloc[0]
print(item)
# Out:
# Chicken Bowl

# %%
#step 10 - for the most ordered, how many items were ordered?
item = chipo[chipo['item_name'] == item]['quantity'].sum()
print(item)
# Out:
# 761

# %%
#step 11 - What was the most ordered item in the choice_description column?
most_ordered_choice = chipo['choice_description'].mode().iloc[0]
print("\nMost ordered item choice description is", most_ordered_choice)
# Out:
# Most ordered item choice description is [Diet Coke]

# %%
#step 12 - How many items were ordered in total
chipo.quantity.sum()
# Out:
# 4972

# %%
#step 13 - Turn the item price into a float • Check the item price type • Create a lambda function and change the type of item price • Check the item price type 
#item price type
chipo.item_price.dtype
# Out:
# dtype('O')

# %%
#change the price type
change_price_Type = lambda x: float(x[1:-1])
chipo.item_price = chipo.item_price.apply(change_price_Type)

# %%
chipo.item_price.dtype
# Out:
# dtype('float64')

# %%
#step 14 - How much was the revenue for the period in the dataset?/
#revenue for a dataset
revenue = (chipo['quantity']* chipo['item_price']).sum()
print("\nRevenue for the period in dataset:", revenue)
# Out:
# Revenue for the period in dataset: 39237.02

# %%
#step 15 -total orders made
number_orders = chipo.order_id.value_counts().count()
print(number_orders)
# Out:
# 1834

# %%
#step 16 - average revenue per order
avg_rev_per_order = revenue / number_orders
print(avg_rev_per_order)
# Out:
# 21.39423118865867

# %%
#step 17 - How many different items are sold?
chipo.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# Question 6
#
# Create a line plot showing the number of marriages and divorces per capita in the U.S. between 1867 and 2014. Label both lines and show the legend. Don't forget to label your axes!

# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
m_d = pd.read_csv(r"C:\Users\13437\Downloads\us-marriages-divorces-1867-2014.csv")
fig, ax = plt.subplots()
 
ax.plot(m_d.Year,m_d.Marriages_per_1000,label='Marriages per capita')
 
ax.plot(m_d.Year,m_d.Divorces_per_1000,label='Divorces per capita')
 
ax.legend()
 
plt.show()

# %% [markdown]
# Question 7
#
# Create a vertical bar chart comparing the number of marriages and divorces per capita in the U.S. between 1900, 1950, and 2000. Don't forget to label your axes!

# %%
data = pd.read_csv(r"C:\Users\13437\Downloads\us-marriages-divorces-1867-2014.csv")
new_Data = data.loc[data.Year.isin([1900,1950,2000]),['Year','Marriages_per_1000','Divorces_per_1000']]
new_Data
# Out:
#      Year  Marriages_per_1000  Divorces_per_1000
# 33   1900                 9.3                0.7
# 83   1950                11.0                2.5
# 133  2000                 8.2                3.3

# %%
new_Data[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
plt.title("Marriages and Divorces Per 1000", color = 'Orange', fontsize = 18)
plt.xlabel('Year', color = 'Black', fontsize = 15)
plt.ylabel('Capita', color = 'Black', fontsize = 15)
positions = (0,1,2)
labels = ("1900", "1950", "2000")
plt.xticks(positions, labels)
# Out:
# C:\Users\13437\AppData\Local\Temp\ipykernel_17240\2229524231.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   new_Data[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
# ([<matplotlib.axis.XTick at 0x155b8943700>,
# ...
#  [Text(0, 0, '1900'), Text(1, 0, '1950'), Text(2, 0, '2000')])

# %%
data[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
plt.title("Marriages and Divorces Per 1000", color = 'Blue', fontsize = 18)
plt.xlabel('Year', color = 'Black', fontsize = 15)
plt.ylabel('Capita', color = 'Black', fontsize = 15)
# Out:
# C:\Users\13437\AppData\Local\Temp\ipykernel_17240\980469350.py:1: FutureWarning: Passing a set as an indexer is deprecated and will raise in a future version. Use a list instead.
#   data[{'Marriages_per_1000','Divorces_per_1000'}].plot.bar()
# Text(0, 0.5, 'Capita')

# %% [markdown]
# Question 8
#
# Create a horizontal bar chart that compares the deadliest actors in Hollywood. Sort the actors by their kill count and label each bar with the corresponding actor's name. Don't forget to label your axes!

# %%
data = pd.read_csv('actor_kill_counts.csv')
new_Data = data.sort_values("Count", ascending = True)
new_Data
# Out:
#                    Actor  Count
# 9          Wesley Snipes    193
# 3             Clive Owen    194
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 2         Clint Eastwood    207
# 8    Tomisaburo Wakayama    226
# 4         Dolph Lundgren    239
# 7     Sylvester Stallone    267
# 1           Chow Yun-Fat    295
# 0  Arnold Schwarzenegger    369

# %%
new_Data.plot.barh(x='Actor', y='Count', color = '#FFAE39')
plt.title('Actors Kill Count', fontsize=20, color = 'Green')
plt.xlabel('Count of kills', color = 'Black', fontsize = 17)
plt.ylabel('Actor', color = 'Black', fontsize = 17)
# Out:
# Text(0, 0.5, 'Actor')

# %% [markdown]
# Question 9
#
# Create a pie chart showing the fraction of all Roman Emperors that were assassinated.  Make sure that the pie chart is an even circle, labels the categories, and shows the percentage breakdown of the categories.

# %%
data = pd.read_csv('roman-emperor-reigns.csv')
data.tail()
# Out:
#            Emperor  Length_of_Reign         Cause_of_Death
# 63   Valentinian I             11.0         Natural causes
# 64          Valens             14.0       Killed in battle
# 65         Gratian             16.0           Assassinated
# 66  Valentinian II             17.0  Possibly assassinated
# 67    Theodosius I             16.0         Natural causes

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
sns.set()

new_data = data.groupby("Cause_of_Death")['Emperor'].count()
new_data
# Out:
# Cause_of_Death
# Assassinated             22
# Died in captivity         1
# Executed                  3
# Illness                   5
# Killed in battle          8
# Natural causes           16
# Possibly assassinated     8
# Suicide                   5
# Name: Emperor, dtype: int64

# %%
new_data.plot.pie(autopct="%.1f%%", figsize = (10,10) , fontsize = 22, ylabel = '', explode=[0.01]*8)
plt.title("Roman Emperor's Cause of Death", color = 'Black', fontsize = 20, fontweight = 'bold')
# Out:
# Text(0.5, 1.0, "Roman Emperor's Cause of Death")

# %% [markdown]
# Question 10
#
# Create a scatter plot showing the relationship between the total revenue earned by arcades and the number of Computer Science PhDs awarded in the U.S. between 2000 and 2009.

# %%
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
data.head()
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

colours = ['#C4E57D','#2AC280','#FFAE39','#DC5B3B','#52E397','#C5CBA3','#9CD5F6','#6E50D9','#9A5E59','#9BC8F5']

data.plot.scatter(x='Total Arcade Revenue (billions)',
                  y='Computer Science Doctorates Awarded (US)', c=colours , s = 50, figsize = (5,4))

plt.title('Revenue Vs CS Doctorates', color = 'Black', fontsize = 16)
plt.xlabel('Total Arcade Revenue (billions)' , color = 'Black', fontsize = 12)
plt.ylabel('CS Doctorates Awarded', color = 'Black', fontsize = 10)
# Out:
# Text(0, 0.5, 'CS Doctorates Awarded')
